# %%
# Import SQLAlchemy and other dependencies here
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from sqlalchemy import Column, Float, Integer, String, Date
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

import pandas as pd
import numpy as np

# %%
# MatPlotLib/NumPy/SciPy
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
engine = create_engine('postgresql://postgres:Teamjack1640@localhost:5432/Project_2_DB')
connection = engine.connect()

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# %%
# Collect the names of tables within the database
inspector.get_table_names()
# Out:
# ['marine_mammal']

# %%
# Using the inspector to print the column names within the 'marine_mammal' table and its types
columns = inspector.get_columns('marine_mammal')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id VARCHAR(100)
# species VARCHAR(65)
# quantity INTEGER
# description VARCHAR(500)
# url VARCHAR(200)
# latitude NUMERIC
# longitude NUMERIC
# location VARCHAR
# sighted_at DATE
# created_at DATE
# updated_at DATE
# orca_type VARCHAR
# orca_pod VARCHAR

# %%
#create marine_mammal class
class marine_mammal(Base):
    __tablename__ = 'marine_mammal'
    
    id = Column (String, primary_key=True)
    species = Column (String)
    quantity = Column (Integer)
    description = Column (String)
    url = Column (String)
    latitude = Column (Float)
    longitude = Column (Float)
    location = Column (String)
    sighted_at = Column (Date)
    created_at = Column (Date)
    updated_at = Column (Date)
    orca_type = Column (String)
    orca_pod = Column (String)

# %%
session = Session(engine)

# %%
marine_mammal_data = pd.read_sql("select * from marine_mammal", connection)

# %%
marine_mammal_data.head(20)
# Out:
#                           id          species  quantity  \
# 0   5a049b7e686f743ec5040000             orca       5.0
# 1   59d039a0686f743ec5020000  harbor porpoise      20.0
# 2   59ab6d65686f747484140000         humpback       1.0
# 3   597d058d686f7474840b0000         humpback       1.0
# 4   596b516e686f747484090000         humpback       1.0
# 5   594fc3d6686f747484060000             orca      14.0
# 6   594192af686f747484040000       gray whale       1.0
# 7   5a84bbba686f74490f901d00             orca       NaN
# 8   5a84ba92686f74490f4e1700             orca       NaN
# 9   5a84ba91686f74490f481700             orca       NaN
# 10  5a84bbb7686f74490f821d00             orca       NaN
# 11  5a84bbb0686f74490f5e1d00             orca       NaN
# 12  5a84ba90686f74490f441700             orca       NaN
# 13  5a84ba90686f74490f461700             orca       NaN
# 14  5a84bab7686f74490f121800             orca       NaN
# 15  5a84bb9d686f74490ff61c00             orca       NaN
# 16  5a84ba99686f74490f741700             orca       NaN
# 17  5a84ba97686f74490f6a1700             orca       NaN
# 18  5a84ba96686f74490f621700             orca       NaN
# 19  5a84ba95686f74490f601700             orca       NaN
#
#                                           description  \
# 0   Spotted from the Edmonds-Kingston ferry, near ...
# 1   From the Inn at Langley looking east there was...
# 2   heading north in the Tacoma narrows,, between ...
# 3   A large splash (breech?) first observed off Ke...
# 4   On train near picnic point (south of Mukilteo)...
# 5   Passing north close to shore at eagle point.  ...
# 6   Observed a whale maybe gray, not orca from blu...
# 7                       Imported by The Whale Museum.
# 8                       Imported by The Whale Museum.
# 9                       Imported by The Whale Museum.
# 10                      Imported by The Whale Museum.
# 11                      Imported by The Whale Museum.
# 12                      Imported by The Whale Museum.
# 13                      Imported by The Whale Museum.
# 14                      Imported by The Whale Museum.
# 15                      Imported by The Whale Museum.
# 16                      Imported by The Whale Museum.
# 17                      Imported by The Whale Museum.
# 18                      Imported by The Whale Museum.
# 19                      Imported by The Whale Museum.
#
#                                                   url   latitude   longitude  \
# 0   http://hotline.whalemuseum.org/sightings/5a049...  47.799530 -122.479967
# 1   http://hotline.whalemuseum.org/sightings/59d03...  48.047448 -122.404776
